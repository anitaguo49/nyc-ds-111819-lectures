# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'ed8v7wLt_hE4TBRBsMZEdw' #Your client ID goes here (as a string)

api_key = 'WnAwXMZoPDgkIP5kynJgDvzXW2iQvyObxw-ARTwvPz25MD4k0oP9Jj3bmKsYva9xrbMrH1lbUXLwLxLUJwsXZbS80ZeF1blDEKWQ20aKlGbR4KvIXjT5Yg5VLmLpXXYx'
##Your api key goes here (as a string)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }
#Bearer comes from Yelp site

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'food'

#where do you want to perform this search
location = 'NYC'

# what is your other parameter you want to search against
status = True

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "open_now" : status
                
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
#this is in bytes
response.text 
#response.content # will return in bytes
# Out:
# '{"businesses": [{"id": "nAcVK-Y1_ojsRF_04o-x-A", "alias": "yin-ji-chang-fen-rice-roll-new-york", "name": "Yin Ji Chang Fen Rice Roll", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/H4q3J5xPjnon8VLXfKpVGw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/yin-ji-chang-fen-rice-roll-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw", "review_count": 103, "categories": [{"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}, {"alias": "dimsum", "title": "Dim Sum"}, {"alias": "cantonese", "title": "Cantonese"}], "rating": 3.5, "coordinates": {"latitude": 40.71583, "longitude": -73.999336}, "transactions": [], "price": "$$", "location": {"address1": "91 Bayard St", "address2": "", "address3": null, "city": "New York", "zip_code": "10013", "country": "US", "state": "NY", "display_address": ["91 Bayard St", "New York, NY 10013"]}, "phone": "+12122274888", "display_phone": "(212) 227-4888", "distance": 1230.5127754823745}, {"id": "-86K6KX3HlUwkWTWRO3VAQ", "alias": "kyuramen-flushing", "name": "KYURAMEN", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/xVklnMIpl3D73zqcxYSuXw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kyuramen-flushing?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw", "review_count": 129, "categories": [{"alias": "ramen", "title": "Ramen"}], "rating": 4.5, "coordinates": {"latitude": 40.76051, "longitude": -73.83339}, "transactions": ["restaurant_reservation"], "price": "$$", "location": {"address1": "133-42 37th Ave", "address2": null, "address3": "", "city": "Flushing", "zip_code": "11354", "country": "US", "state": "NY", "display_address": ["133-42 37th Ave", "Flushing, NY 11354"]}, "phone": "+19172852332", "display_phone": "(917) 285-2332", "distance": 14876.438633707987}, {"id": "1TZ9CzGDGdAGCADjoYaliA", "alias": "otaku-katsu-new-york-2", "name": "Otaku Katsu", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3re0gN6SlWuhOkkaCjAgeg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/otaku-katsu-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw", "review_count": 31, "categories": [{"alias": "japanese", "title": "Japanese"}, {"alias": "comfortfood", "title": "Comfort Food"}], "rating": 4.5, "coordinates": {"latitude": 40.719384, "longitude": -73.986529}, "transactions": ["delivery", "pickup"], "location": {"address1": "137 Rivington St", "address2": null, "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["137 Rivington St", "New York, NY 10002"]}, "phone": "+19173883924", "display_phone": "(917) 388-3924", "distance": 1682.4450038578605}, {"id": "X8ZS-dgiMIJvhwf9SaDnjw", "alias": "wah-fung-no-1-fast-food-new-york-3", "name": "Wah Fung No 1 Fast Food", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw", "review_count": 1358, "categories": [{"alias": "chinese", "title": "Chinese"}, {"alias": "hotdogs", "title": "Fast Food"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": 40.71735, "longitude": -73.99457}, "transactions": [], "price": "$", "location": {"address1": "79 Chrystie St", "address2": "", "address3": "", "city": "New York", "zip_code": "10002", "country": "US", "state": "NY", "display_address": ["79 Chrystie St", "New York, NY 10002"]}, "phone": "+12129255175", "display_phone": "(212) 925-5175", "distance": 1323.2851807067286}, {"id": "jnEv25Y2DosTq2sNnvmC9g", "alias": "los-tacos-no-1-new-york", "name": "Los Tacos No.1", "image_url": "https ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'nAcVK-Y1_ojsRF_04o-x-A',
#    'alias': 'yin-ji-chang-fen-rice-roll-new-york',
#    'name': 'Yin Ji Chang Fen Rice Roll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H4q3J5xPjnon8VLXfKpVGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yin-ji-chang-fen-rice-roll-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 103,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71583, 'longitude': -73.999336},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '91 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 Bayard St', 'New York, NY 10013']},
#    'phone': '+12122274888',
#    'display_phone': '(212) 227-4888',
#    'distance': 1230.5127754823745},
#   {'id': '-86K6KX3HlUwkWTWRO3VAQ',
#    'alias': 'kyuramen-flushing',
#    'name': 'KYURAMEN',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xVklnMIpl3D73zqcxYSuXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyuramen-flushing?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 129,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76051, 'longitude': -73.83339},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '133-42 37th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133-42 37th Ave', 'Flushing, NY 11354']},
#    'phone': '+19172852332',
#    'display_phone': '(917) 285-2332',
#    'distance': 14876.438633707987},
#   {'id': '1TZ9CzGDGdAGCADjoYaliA',
#    'alias': 'otaku-katsu-new-york-2',
#    'name': 'Otaku Katsu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3re0gN6SlWuhOkkaCjAgeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otaku-katsu-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 31,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719384, 'longitude': -73.986529},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '137 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Rivington St', 'New York, NY 10002']},
#    'phone': '+19173883924',
#    'display_phone': '(917) 388-3924',
#    'distance': 1682.4450038578605},
#   {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#    'alias': 'wah-fung-no-1-fast-food-new-york-3',
#    'name': 'Wah Fung No 1 Fast Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1358,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129255175',
#    'display_phone': '(212) 925-5175',
#    'distance': 1323.2851807067286},
#   {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#    'alias': 'los-tacos-no-1-new-york',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 2868,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12122560343',
#    'display_phone': '(212) 256-0343',
#    'distance': 4244.358699250552},
#   {'id': 'oe8GEFE4QLFAKt87y7zcgA',
#    'alias': 'very-fresh-noodles-new-york',
#    'name': 'Very Fresh Noodles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXp6g4K-ysN7Js9LzSxFBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/very-fresh-noodles-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 929,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7423387008486, 'longitude': -74.00625},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '425 W 15th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 W 15th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4224.33101069106},
#   {'id': 'SULHf6nGQ8sK0UpG1XU30w',
#    'alias': 'los-tacos-no-1-new-york-3',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5wEe4FCwda16knmBHSsX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1600,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7575067, 'longitude': -73.9877717},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '229 W 43rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12125744696',
#    'display_phone': '(212) 574-4696',
#    'distance': 5815.027424033859},
#   {'id': 'FZYmp5c1VtWNfe635G_wsQ',
#    'alias': 'taste-of-heaven-brooklyn',
#    'name': 'Taste of Heaven',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SNiWVU6gk8UyVFS44LtdKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-heaven-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 129,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.717115, 'longitude': -73.940613},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '251 Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 Jackson St', 'Brooklyn, NY 11211']},
#    'phone': '+17185763146',
#    'display_phone': '(718) 576-3146',
#    'distance': 4706.918985703231},
#   {'id': 'GLf8_rOnkszkGmPAiMzO9Q',
#    'alias': 'bread-and-spread-dumbo',
#    'name': 'Bread & Spread',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMT03iEizZOtc_Cwe5wQbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-spread-dumbo?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 137,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7025945, 'longitude': -73.9869119},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '151 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Front St', 'Dumbo, NY 11201']},
#    'phone': '+17186252220',
#    'display_phone': '(718) 625-2220',
#    'distance': 698.2848912388458},
#   {'id': 'AR_0QV4O12sHojkky_IMkg',
#    'alias': 'canal-street-market-new-york',
#    'name': 'Canal Street Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXqb8XpUt3bkKgjATIXFTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canal-street-market-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 176,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71897, 'longitude': -74.00102},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '265 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 Canal St', 'New York, NY 10013']},
#    'phone': '+16466941655',
#    'display_phone': '(646) 694-1655',
#    'distance': 1606.6824281755084},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 643,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1851.5130715768003},
#   {'id': 'Ms3CAGddVbgetiQrpzqxPQ',
#    'alias': 'hometown-bar-b-que-brooklyn-3',
#    'name': 'Hometown Bar-B-Que',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eo9NJvaF8j9HLa0GX9yNUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hometown-bar-b-que-brooklyn-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1307,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6748965703426,
#     'longitude': -74.0160489746129},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '454 Van Brunt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['454 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+13472944644',
#    'display_phone': '(347) 294-4644',
#    'distance': 3860.4357473559635},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1380,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1866.3436634084576},
#   {'id': 'hNFe8WhCibrqT4sFcZmAgw',
#    'alias': 'kong-sihk-tong-港食堂-new-york',
#    'name': 'Kong Sihk Tong 港食堂',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G00GzDuAyjgtBHEcjR_lLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kong-sihk-tong-%E6%B8%AF%E9%A3%9F%E5%A0%82-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 206,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71542, 'longitude': -73.99813},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '65 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Bayard St', 'New York, NY 10013']},
#    'phone': '+16468506140',
#    'display_phone': '(646) 850-6140',
#    'distance': 1153.870812287678},
#   {'id': 'gHdejB1Mx2P5UjAgZ6BT2w',
#    'alias': 'cheeky-sandwiches-new-york',
#    'name': 'Cheeky Sandwiches',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XGGQOLhQIL-Y8Y-CdHeOPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheeky-sandwiches-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1141,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158, 'longitude': -73.99169},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '35 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465048132',
#    'display_phone': '(646) 504-8132',
#    'distance': 1165.1002553885921},
#   {'id': 'zdB4nA0Xpyxhi5oIt6wVng',
#    'alias': 'joju-new-york-2',
#    'name': 'JoJu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DPAOTKX7uRe0ex5ebj0eHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joju-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 58,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7558, 'longitude': -73.97874},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '555 5th Ave',
#     'address2': '46th St. Entrance, Between 5th & Madison Ave',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['555 5th Ave',
#      '46th St. Entrance, Between 5th & Madison Ave',
#      'New York, NY 10017']},
#    'phone': '+13322042278',
#    'display_phone': '(332) 204-2278',
#    'distance': 5736.559681647211},
#   {'id': 'olRNNJCJ2TJvPRmjBiOcGA',
#    'alias': 'silky-kitchen-new-york-3',
#    'name': 'Silky Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Pp9_g_8rHI5_0GlVSmVCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silky-kitchen-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 197,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73297, 'longitude': -73.98829},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '137 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 E 13th St', 'New York, NY 10003']},
#    'phone': '+16468500635',
#    'display_phone': '(646) 850-0635',
#    'distance': 3099.0828505233635},
#   {'id': 'CnFp2AUFkzsnfh7MQD3yag',
#    'alias': 'boba-fries-elmhurst',
#    'name': 'Boba Fries',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qjr4Lbzw61eRUz-hrp0AYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boba-fries-elmhurst?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 32,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432094, 'longitude': -73.8830931},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8121 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8121 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188988868',
#    'display_phone': '(718) 898-8868',
#    'distance': 10268.667857146653},
#   {'id': 'z3TwiFWdJUvY9tW8QMEseQ',
#    'alias': 'taco-dumbo-brooklyn',
#    'name': 'Taco Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/25eTHDdSHG5vAVkKeWazWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-dumbo-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 184,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.700601, 'longitude': -73.988467},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '56 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+13472020306',
#    'display_phone': '(347) 202-0306',
#    'distance': 728.9122627706757},
#   {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#    'alias': 'lukes-lobster-fidi-new-york',
#    'name': "Luke's Lobster FiDi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1132,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 S William St', 'New York, NY 10004']},
#    'phone': '+12127471700',
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.7033987694713}],
#  'total': 30000,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'nAcVK-Y1_ojsRF_04o-x-A',
#    'alias': 'yin-ji-chang-fen-rice-roll-new-york',
#    'name': 'Yin Ji Chang Fen Rice Roll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H4q3J5xPjnon8VLXfKpVGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yin-ji-chang-fen-rice-roll-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 103,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.71583, 'longitude': -73.999336},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '91 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['91 Bayard St', 'New York, NY 10013']},
#    'phone': '+12122274888',
#    'display_phone': '(212) 227-4888',
#    'distance': 1230.5127754823745},
#   {'id': '-86K6KX3HlUwkWTWRO3VAQ',
#    'alias': 'kyuramen-flushing',
#    'name': 'KYURAMEN',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xVklnMIpl3D73zqcxYSuXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kyuramen-flushing?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 129,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76051, 'longitude': -73.83339},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '133-42 37th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11354',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['133-42 37th Ave', 'Flushing, NY 11354']},
#    'phone': '+19172852332',
#    'display_phone': '(917) 285-2332',
#    'distance': 14876.438633707987},
#   {'id': '1TZ9CzGDGdAGCADjoYaliA',
#    'alias': 'otaku-katsu-new-york-2',
#    'name': 'Otaku Katsu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3re0gN6SlWuhOkkaCjAgeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/otaku-katsu-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 31,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.719384, 'longitude': -73.986529},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '137 Rivington St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 Rivington St', 'New York, NY 10002']},
#    'phone': '+19173883924',
#    'display_phone': '(917) 388-3924',
#    'distance': 1682.4450038578605},
#   {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#    'alias': 'wah-fung-no-1-fast-food-new-york-3',
#    'name': 'Wah Fung No 1 Fast Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1358,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129255175',
#    'display_phone': '(212) 925-5175',
#    'distance': 1323.2851807067286},
#   {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#    'alias': 'los-tacos-no-1-new-york',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 2868,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '75 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12122560343',
#    'display_phone': '(212) 256-0343',
#    'distance': 4244.358699250552},
#   {'id': 'oe8GEFE4QLFAKt87y7zcgA',
#    'alias': 'very-fresh-noodles-new-york',
#    'name': 'Very Fresh Noodles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXp6g4K-ysN7Js9LzSxFBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/very-fresh-noodles-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 929,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7423387008486, 'longitude': -74.00625},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '425 W 15th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['425 W 15th St', 'New York, NY 10011']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4224.33101069106},
#   {'id': 'SULHf6nGQ8sK0UpG1XU30w',
#    'alias': 'los-tacos-no-1-new-york-3',
#    'name': 'Los Tacos No.1',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5wEe4FCwda16knmBHSsX0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1600,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7575067, 'longitude': -73.9877717},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '229 W 43rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['229 W 43rd St', 'New York, NY 10036']},
#    'phone': '+12125744696',
#    'display_phone': '(212) 574-4696',
#    'distance': 5815.027424033859},
#   {'id': 'FZYmp5c1VtWNfe635G_wsQ',
#    'alias': 'taste-of-heaven-brooklyn',
#    'name': 'Taste of Heaven',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SNiWVU6gk8UyVFS44LtdKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-heaven-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 129,
#    'categories': [{'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.717115, 'longitude': -73.940613},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '251 Jackson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['251 Jackson St', 'Brooklyn, NY 11211']},
#    'phone': '+17185763146',
#    'display_phone': '(718) 576-3146',
#    'distance': 4706.918985703231},
#   {'id': 'GLf8_rOnkszkGmPAiMzO9Q',
#    'alias': 'bread-and-spread-dumbo',
#    'name': 'Bread & Spread',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMT03iEizZOtc_Cwe5wQbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-and-spread-dumbo?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 137,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7025945, 'longitude': -73.9869119},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '151 Front St',
#     'address2': None,
#     'address3': '',
#     'city': 'Dumbo',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['151 Front St', 'Dumbo, NY 11201']},
#    'phone': '+17186252220',
#    'display_phone': '(718) 625-2220',
#    'distance': 698.2848912388458},
#   {'id': 'AR_0QV4O12sHojkky_IMkg',
#    'alias': 'canal-street-market-new-york',
#    'name': 'Canal Street Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXqb8XpUt3bkKgjATIXFTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/canal-street-market-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 176,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71897, 'longitude': -74.00102},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '265 Canal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['265 Canal St', 'New York, NY 10013']},
#    'phone': '+16466941655',
#    'display_phone': '(646) 694-1655',
#    'distance': 1606.6824281755084},
#   {'id': 'HFOiW4RvijuoblE4DD3JwA',
#    'alias': 'dekalb-market-hall-brooklyn-2',
#    'name': 'Dekalb Market Hall',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 643,
#    'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '445 Albee Square W',
#     'address2': 'Basement Level',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['445 Albee Square W',
#      'Basement Level',
#      'Brooklyn, NY 11201']},
#    'phone': '+19293596555',
#    'display_phone': '(929) 359-6555',
#    'distance': 1851.5130715768003},
#   {'id': 'Ms3CAGddVbgetiQrpzqxPQ',
#    'alias': 'hometown-bar-b-que-brooklyn-3',
#    'name': 'Hometown Bar-B-Que',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eo9NJvaF8j9HLa0GX9yNUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hometown-bar-b-que-brooklyn-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1307,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6748965703426,
#     'longitude': -74.0160489746129},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '454 Van Brunt St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['454 Van Brunt St', 'Brooklyn, NY 11231']},
#    'phone': '+13472944644',
#    'display_phone': '(347) 294-4644',
#    'distance': 3860.4357473559635},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1380,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1866.3436634084576},
#   {'id': 'hNFe8WhCibrqT4sFcZmAgw',
#    'alias': 'kong-sihk-tong-港食堂-new-york',
#    'name': 'Kong Sihk Tong 港食堂',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G00GzDuAyjgtBHEcjR_lLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kong-sihk-tong-%E6%B8%AF%E9%A3%9F%E5%A0%82-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 206,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71542, 'longitude': -73.99813},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '65 Bayard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 Bayard St', 'New York, NY 10013']},
#    'phone': '+16468506140',
#    'display_phone': '(646) 850-6140',
#    'distance': 1153.870812287678},
#   {'id': 'gHdejB1Mx2P5UjAgZ6BT2w',
#    'alias': 'cheeky-sandwiches-new-york',
#    'name': 'Cheeky Sandwiches',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XGGQOLhQIL-Y8Y-CdHeOPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cheeky-sandwiches-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1141,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7158, 'longitude': -73.99169},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '35 Orchard St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465048132',
#    'display_phone': '(646) 504-8132',
#    'distance': 1165.1002553885921},
#   {'id': 'zdB4nA0Xpyxhi5oIt6wVng',
#    'alias': 'joju-new-york-2',
#    'name': 'JoJu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DPAOTKX7uRe0ex5ebj0eHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joju-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 58,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7558, 'longitude': -73.97874},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '555 5th Ave',
#     'address2': '46th St. Entrance, Between 5th & Madison Ave',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['555 5th Ave',
#      '46th St. Entrance, Between 5th & Madison Ave',
#      'New York, NY 10017']},
#    'phone': '+13322042278',
#    'display_phone': '(332) 204-2278',
#    'distance': 5736.559681647211},
#   {'id': 'olRNNJCJ2TJvPRmjBiOcGA',
#    'alias': 'silky-kitchen-new-york-3',
#    'name': 'Silky Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Pp9_g_8rHI5_0GlVSmVCBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silky-kitchen-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 197,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73297, 'longitude': -73.98829},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '137 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['137 E 13th St', 'New York, NY 10003']},
#    'phone': '+16468500635',
#    'display_phone': '(646) 850-0635',
#    'distance': 3099.0828505233635},
#   {'id': 'CnFp2AUFkzsnfh7MQD3yag',
#    'alias': 'boba-fries-elmhurst',
#    'name': 'Boba Fries',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qjr4Lbzw61eRUz-hrp0AYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boba-fries-elmhurst?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 32,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432094, 'longitude': -73.8830931},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '8121 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8121 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188988868',
#    'display_phone': '(718) 898-8868',
#    'distance': 10268.667857146653},
#   {'id': 'z3TwiFWdJUvY9tW8QMEseQ',
#    'alias': 'taco-dumbo-brooklyn',
#    'name': 'Taco Dumbo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/25eTHDdSHG5vAVkKeWazWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taco-dumbo-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 184,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.700601, 'longitude': -73.988467},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '56 Prospect St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['56 Prospect St', 'Brooklyn, NY 11201']},
#    'phone': '+13472020306',
#    'display_phone': '(347) 202-0306',
#    'distance': 728.9122627706757},
#   {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#    'alias': 'lukes-lobster-fidi-new-york',
#    'name': "Luke's Lobster FiDi",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#    'review_count': 1132,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['26 S William St', 'New York, NY 10004']},
#    'phone': '+12127471700',
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.7033987694713}],
#  'total': 30000,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
# total
# <class 'int'>
#
#
# region
# <class 'dict'>

# %%
data['total']
# Out:
# 30000

# %%
data['businesses']
# Out:
# [{'id': 'nAcVK-Y1_ojsRF_04o-x-A',
#   'alias': 'yin-ji-chang-fen-rice-roll-new-york',
#   'name': 'Yin Ji Chang Fen Rice Roll',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H4q3J5xPjnon8VLXfKpVGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yin-ji-chang-fen-rice-roll-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 103,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'cantonese', 'title': 'Cantonese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.71583, 'longitude': -73.999336},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '91 Bayard St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['91 Bayard St', 'New York, NY 10013']},
#   'phone': '+12122274888',
#   'display_phone': '(212) 227-4888',
#   'distance': 1230.5127754823745},
#  {'id': '-86K6KX3HlUwkWTWRO3VAQ',
#   'alias': 'kyuramen-flushing',
#   'name': 'KYURAMEN',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xVklnMIpl3D73zqcxYSuXw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kyuramen-flushing?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 129,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76051, 'longitude': -73.83339},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '133-42 37th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Flushing',
#    'zip_code': '11354',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['133-42 37th Ave', 'Flushing, NY 11354']},
#   'phone': '+19172852332',
#   'display_phone': '(917) 285-2332',
#   'distance': 14876.438633707987},
#  {'id': '1TZ9CzGDGdAGCADjoYaliA',
#   'alias': 'otaku-katsu-new-york-2',
#   'name': 'Otaku Katsu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3re0gN6SlWuhOkkaCjAgeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/otaku-katsu-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 31,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.719384, 'longitude': -73.986529},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '137 Rivington St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['137 Rivington St', 'New York, NY 10002']},
#   'phone': '+19173883924',
#   'display_phone': '(917) 388-3924',
#   'distance': 1682.4450038578605},
#  {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#   'alias': 'wah-fung-no-1-fast-food-new-york-3',
#   'name': 'Wah Fung No 1 Fast Food',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1358,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '79 Chrystie St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#   'phone': '+12129255175',
#   'display_phone': '(212) 925-5175',
#   'distance': 1323.2851807067286},
#  {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#   'alias': 'los-tacos-no-1-new-york',
#   'name': 'Los Tacos No.1',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 2868,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '75 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['75 9th Ave', 'New York, NY 10011']},
#   'phone': '+12122560343',
#   'display_phone': '(212) 256-0343',
#   'distance': 4244.358699250552},
#  {'id': 'oe8GEFE4QLFAKt87y7zcgA',
#   'alias': 'very-fresh-noodles-new-york',
#   'name': 'Very Fresh Noodles',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NXp6g4K-ysN7Js9LzSxFBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/very-fresh-noodles-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 929,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7423387008486, 'longitude': -74.00625},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '425 W 15th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['425 W 15th St', 'New York, NY 10011']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 4224.33101069106},
#  {'id': 'SULHf6nGQ8sK0UpG1XU30w',
#   'alias': 'los-tacos-no-1-new-york-3',
#   'name': 'Los Tacos No.1',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5wEe4FCwda16knmBHSsX0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1600,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7575067, 'longitude': -73.9877717},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '229 W 43rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['229 W 43rd St', 'New York, NY 10036']},
#   'phone': '+12125744696',
#   'display_phone': '(212) 574-4696',
#   'distance': 5815.027424033859},
#  {'id': 'FZYmp5c1VtWNfe635G_wsQ',
#   'alias': 'taste-of-heaven-brooklyn',
#   'name': 'Taste of Heaven',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SNiWVU6gk8UyVFS44LtdKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taste-of-heaven-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 129,
#   'categories': [{'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.717115, 'longitude': -73.940613},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '251 Jackson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['251 Jackson St', 'Brooklyn, NY 11211']},
#   'phone': '+17185763146',
#   'display_phone': '(718) 576-3146',
#   'distance': 4706.918985703231},
#  {'id': 'GLf8_rOnkszkGmPAiMzO9Q',
#   'alias': 'bread-and-spread-dumbo',
#   'name': 'Bread & Spread',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMT03iEizZOtc_Cwe5wQbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bread-and-spread-dumbo?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 137,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7025945, 'longitude': -73.9869119},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '151 Front St',
#    'address2': None,
#    'address3': '',
#    'city': 'Dumbo',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['151 Front St', 'Dumbo, NY 11201']},
#   'phone': '+17186252220',
#   'display_phone': '(718) 625-2220',
#   'distance': 698.2848912388458},
#  {'id': 'AR_0QV4O12sHojkky_IMkg',
#   'alias': 'canal-street-market-new-york',
#   'name': 'Canal Street Market',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gXqb8XpUt3bkKgjATIXFTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/canal-street-market-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 176,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71897, 'longitude': -74.00102},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '265 Canal St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['265 Canal St', 'New York, NY 10013']},
#   'phone': '+16466941655',
#   'display_phone': '(646) 694-1655',
#   'distance': 1606.6824281755084},
#  {'id': 'HFOiW4RvijuoblE4DD3JwA',
#   'alias': 'dekalb-market-hall-brooklyn-2',
#   'name': 'Dekalb Market Hall',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 643,
#   'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '445 Albee Square W',
#    'address2': 'Basement Level',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['445 Albee Square W',
#     'Basement Level',
#     'Brooklyn, NY 11201']},
#   'phone': '+19293596555',
#   'display_phone': '(929) 359-6555',
#   'distance': 1851.5130715768003},
#  {'id': 'Ms3CAGddVbgetiQrpzqxPQ',
#   'alias': 'hometown-bar-b-que-brooklyn-3',
#   'name': 'Hometown Bar-B-Que',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eo9NJvaF8j9HLa0GX9yNUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hometown-bar-b-que-brooklyn-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1307,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'smokehouse', 'title': 'Smokehouse'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6748965703426,
#    'longitude': -74.0160489746129},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '454 Van Brunt St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['454 Van Brunt St', 'Brooklyn, NY 11231']},
#   'phone': '+13472944644',
#   'display_phone': '(347) 294-4644',
#   'distance': 3860.4357473559635},
#  {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#   'alias': 'bocaphê-new-york-3',
#   'name': 'BoCaphe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1380,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '222 Lafayette St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#   'phone': '+16468821939',
#   'display_phone': '(646) 882-1939',
#   'distance': 1866.3436634084576},
#  {'id': 'hNFe8WhCibrqT4sFcZmAgw',
#   'alias': 'kong-sihk-tong-港食堂-new-york',
#   'name': 'Kong Sihk Tong 港食堂',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G00GzDuAyjgtBHEcjR_lLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kong-sihk-tong-%E6%B8%AF%E9%A3%9F%E5%A0%82-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 206,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hkcafe', 'title': 'Hong Kong Style Cafe'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71542, 'longitude': -73.99813},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '65 Bayard St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['65 Bayard St', 'New York, NY 10013']},
#   'phone': '+16468506140',
#   'display_phone': '(646) 850-6140',
#   'distance': 1153.870812287678},
#  {'id': 'gHdejB1Mx2P5UjAgZ6BT2w',
#   'alias': 'cheeky-sandwiches-new-york',
#   'name': 'Cheeky Sandwiches',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XGGQOLhQIL-Y8Y-CdHeOPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cheeky-sandwiches-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1141,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7158, 'longitude': -73.99169},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '35 Orchard St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35 Orchard St', 'New York, NY 10002']},
#   'phone': '+16465048132',
#   'display_phone': '(646) 504-8132',
#   'distance': 1165.1002553885921},
#  {'id': 'zdB4nA0Xpyxhi5oIt6wVng',
#   'alias': 'joju-new-york-2',
#   'name': 'JoJu',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DPAOTKX7uRe0ex5ebj0eHQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joju-new-york-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 58,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7558, 'longitude': -73.97874},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '555 5th Ave',
#    'address2': '46th St. Entrance, Between 5th & Madison Ave',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['555 5th Ave',
#     '46th St. Entrance, Between 5th & Madison Ave',
#     'New York, NY 10017']},
#   'phone': '+13322042278',
#   'display_phone': '(332) 204-2278',
#   'distance': 5736.559681647211},
#  {'id': 'olRNNJCJ2TJvPRmjBiOcGA',
#   'alias': 'silky-kitchen-new-york-3',
#   'name': 'Silky Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Pp9_g_8rHI5_0GlVSmVCBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/silky-kitchen-new-york-3?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 197,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73297, 'longitude': -73.98829},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '137 E 13th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['137 E 13th St', 'New York, NY 10003']},
#   'phone': '+16468500635',
#   'display_phone': '(646) 850-0635',
#   'distance': 3099.0828505233635},
#  {'id': 'CnFp2AUFkzsnfh7MQD3yag',
#   'alias': 'boba-fries-elmhurst',
#   'name': 'Boba Fries',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qjr4Lbzw61eRUz-hrp0AYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boba-fries-elmhurst?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 32,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7432094, 'longitude': -73.8830931},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '8121 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'Elmhurst',
#    'zip_code': '11373',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8121 Broadway', 'Elmhurst, NY 11373']},
#   'phone': '+17188988868',
#   'display_phone': '(718) 898-8868',
#   'distance': 10268.667857146653},
#  {'id': 'z3TwiFWdJUvY9tW8QMEseQ',
#   'alias': 'taco-dumbo-brooklyn',
#   'name': 'Taco Dumbo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/25eTHDdSHG5vAVkKeWazWw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/taco-dumbo-brooklyn?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 184,
#   'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'tacos', 'title': 'Tacos'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.700601, 'longitude': -73.988467},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '56 Prospect St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['56 Prospect St', 'Brooklyn, NY 11201']},
#   'phone': '+13472020306',
#   'display_phone': '(347) 202-0306',
#   'distance': 728.9122627706757},
#  {'id': 'kxykwx5qTWBhlMh18MQ82Q',
#   'alias': 'lukes-lobster-fidi-new-york',
#   'name': "Luke's Lobster FiDi",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#   'review_count': 1132,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7046213003984,
#    'longitude': -74.0107793876969},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '26 S William St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10004',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['26 S William St', 'New York, NY 10004']},
#   'phone': '+12127471700',
#   'display_phone': '(212) 747-1700',
#   'distance': 1392.7033987694713}]

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['businesses'][4]
# Out:
# {'id': 'jnEv25Y2DosTq2sNnvmC9g',
#  'alias': 'los-tacos-no-1-new-york',
#  'name': 'Los Tacos No.1',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FU44TYl3PzXsE06G4W5aog/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/los-tacos-no-1-new-york?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#  'review_count': 2868,
#  'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7425547, 'longitude': -74.0060838},
#  'transactions': [],
#  'price': '$',
#  'location': {'address1': '75 9th Ave',
#   'address2': '',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10011',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['75 9th Ave', 'New York, NY 10011']},
#  'phone': '+12122560343',
#  'display_phone': '(212) 256-0343',
#  'distance': 4244.358699250552}

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
business = data['businesses'][10]
business
# Out:
# {'id': 'HFOiW4RvijuoblE4DD3JwA',
#  'alias': 'dekalb-market-hall-brooklyn-2',
#  'name': 'Dekalb Market Hall',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p3HJcEcHV7KuX0XVh30KUA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/dekalb-market-hall-brooklyn-2?adjust_creative=ed8v7wLt_hE4TBRBsMZEdw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ed8v7wLt_hE4TBRBsMZEdw',
#  'review_count': 643,
#  'categories': [{'alias': 'food_court', 'title': 'Food Court'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.691025, 'longitude': -73.983311},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '445 Albee Square W',
#   'address2': 'Basement Level',
#   'address3': None,
#   'city': 'Brooklyn',
#   'zip_code': '11201',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['445 Albee Square W',
#    'Basement Level',
#    'Brooklyn, NY 11201']},
#  'phone': '+19293596555',
#  'display_phone': '(929) 359-6555',
#  'distance': 1851.5130715768003}

# %%
biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['rating'])
#what is ' '.join?

# %%
biz_tuple
# Out:
# ('Dekalb Market Hall',
#  '445 Albee Square W Basement Level Brooklyn, NY 11201',
#  4.0)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
# create a container to hold our parsed data
# loop through our business and parse each individual business
# in the loop, add each individual parsed parsed business to our data container
# return the container with all of the parsed results
def parse_data(list_of_data):
    parsed_result = []
    for business in list_of_data:
        biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['rating'])
        parsed_result.append(biz_tuple)
    return parsed_result

# %%
parse_data(data['businesses'])
# Out:
# [('Yin Ji Chang Fen Rice Roll', '91 Bayard St New York, NY 10013', 3.5),
#  ('KYURAMEN', '133-42 37th Ave Flushing, NY 11354', 4.5),
#  ('Otaku Katsu', '137 Rivington St New York, NY 10002', 4.5),
#  ('Wah Fung No 1 Fast Food', '79 Chrystie St New York, NY 10002', 4.5),
#  ('Los Tacos No.1', '75 9th Ave New York, NY 10011', 4.5),
#  ('Very Fresh Noodles', '425 W 15th St New York, NY 10011', 4.5),
#  ('Los Tacos No.1', '229 W 43rd St New York, NY 10036', 4.5),
#  ('Taste of Heaven', '251 Jackson St Brooklyn, NY 11211', 5.0),
#  ('Bread & Spread', '151 Front St Dumbo, NY 11201', 4.5),
#  ('Canal Street Market', '265 Canal St New York, NY 10013', 4.0),
#  ('Dekalb Market Hall',
#   '445 Albee Square W Basement Level Brooklyn, NY 11201',
#   4.0),
#  ('Hometown Bar-B-Que', '454 Van Brunt St Brooklyn, NY 11231', 4.0),
#  ('BoCaphe', '222 Lafayette St New York, NY 10012', 4.0),
#  ('Kong Sihk Tong 港食堂', '65 Bayard St New York, NY 10013', 4.0),
#  ('Cheeky Sandwiches', '35 Orchard St New York, NY 10002', 4.5),
#  ('JoJu',
#   '555 5th Ave 46th St. Entrance, Between 5th & Madison Ave New York, NY 10017',
#   4.5),
#  ('Silky Kitchen', '137 E 13th St New York, NY 10003', 4.5),
#  ('Boba Fries', '8121 Broadway Elmhurst, NY 11373', 4.5),
#  ('Taco Dumbo', '56 Prospect St Brooklyn, NY 11201', 4.0),
#  ("Luke's Lobster FiDi", '26 S William St New York, NY 10004', 4.5)]
