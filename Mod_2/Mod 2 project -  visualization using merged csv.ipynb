# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("All_Movie_Data.csv")

# %%
df.head(10)
# Out:
#    Rank                                      Movie  World_Wide_Sales  \
# 0     2  The Hobbit: The Battle of the Five Armies         956020000
# 1     3                    Guardians of the Galaxy         772777000
# 2     6                 X-Men: Days of Future Past         746046000
# 3     7        Captain America: The Winter Soldier         714422000
# 4     8             Dawn of the Planet of the Apes         710645000
# 5     9                   The Amazing Spider-Man 2         708982000
# 6    10                               Interstellar         677464000
# 7    11                                 Big Hero 6         657828000
# 8    12                 How to Train Your Dragon 2         621538000
# 9    13                            American Sniper         547426000
#
#    Domestic_Sales  Foriegn_Sales                         Genre  Release_Year  \
# 0     255120000.0    700900000.0            Adventure, Fantasy          2014
# 1     333177000.0    439600000.0     Action, Adventure, Comedy          2014
# 2     233922000.0    512124000.0     Action, Adventure, Sci-Fi          2014
# 3     259767000.0    454655000.0     Action, Adventure, Sci-Fi          2014
# 4     208546000.0    502099000.0      Action, Adventure, Drama          2014
# 5     202854000.0    506128000.0     Action, Adventure, Sci-Fi          2014
# 6     188020000.0    489444000.0      Adventure, Drama, Sci-Fi          2014
# 7     222528000.0    435300000.0  Animation, Action, Adventure          2014
# 8     177003000.0    444535000.0  Animation, Action, Adventure          2014
# 9     350126000.0    197300000.0      Action, Biography, Drama          2014
#
#    IMBD_Rating  Rated  Year_Id
# 0          7.4  PG-13        2
# 1          8.0  PG-13        3
# 2          8.0  PG-13        6
# 3          7.7  PG-13        7
# 4          7.6  PG-13        8
# 5          6.6  PG-13        9
# 6          8.6  PG-13       10
# 7          7.8     PG       11
# 8          7.8     PG       12
# 9          7.3      R       13

# %%
df[['IMBD_Rating','World_Wide_Sales','Foriegn_Sales','Domestic_Sales']]
# Out:
#      IMBD_Rating  World_Wide_Sales  Foriegn_Sales  Domestic_Sales
# 0            7.4         956020000    700900000.0     255120000.0
# 1            8.0         772777000    439600000.0     333177000.0
# 2            8.0         746046000    512124000.0     233922000.0
# 3            7.7         714422000    454655000.0     259767000.0
# 4            7.6         710645000    502099000.0     208546000.0
# ..           ...               ...            ...             ...
# 430          7.3           6863150      4874610.0       1988550.0
# 431          5.5           4554060      1051460.0       3502600.0
# 432          6.7           2414270         3355.0       2410910.0
# 433          6.5           1719160       682420.0       1036740.0
# 434          5.9           1551520        42928.0       1508590.0
#
# [435 rows x 4 columns]

# %%
rating = df['IMBD_Rating']
Worldwide = df['World_Wide_Sales']
plt.scatter(data1, data2, marker='o')
plt.xlabel('IMBD Rating')
plt.ylabel('World Wide Sales')
plt.show()

# %%
with sns.axes_style('white'):
    sns.jointplot(rating,Worldwide, kind='hex',height=10)

# %%
df[['IMBD_Rating','Domestic_Sales']]
# Out:
#      IMBD_Rating  Domestic_Sales
# 0            7.4     255120000.0
# 1            8.0     333177000.0
# 2            8.0     233922000.0
# 3            7.7     259767000.0
# 4            7.6     208546000.0
# ..           ...             ...
# 430          7.3       1988550.0
# 431          5.5       3502600.0
# 432          6.7       2410910.0
# 433          6.5       1036740.0
# 434          5.9       1508590.0
#
# [435 rows x 2 columns]

# %%
with sns.axes_style('white'):
    sns.jointplot(rating,domestic, kind='hex',height=10)

# %%
foreign = df['Foriegn_Sales']

# %%
with sns.axes_style('white'):
    sns.jointplot(rating,foreign, kind='hex',height=10)

# %%
rated = df['Rated']
rated
# Out:
# 0      PG-13
# 1      PG-13
# 2      PG-13
# 3      PG-13
# 4      PG-13
#        ...
# 430        R
# 431        R
# 432        R
# 433        R
# 434        R
# Name: Rated, Length: 435, dtype: object

# %%
rated_list = tuple(df['Rated'].unique())
rated_list
# Out:
# ('PG-13', 'PG', 'R', 'Not Rated', 'G')
