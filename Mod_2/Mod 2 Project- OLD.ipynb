# %%
## Connect to DB server on AWS
import mysql.connector 
import config

cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd
)
cursor = cnx.cursor()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import itertools

# %%
# #Create new DB
# cursor.execute("CREATE DATABASE Movie_Project")

# %%
cnx.database = 'Movie_Project'

# %%
# #create a table for Movie_info
# create_table_movie_info = '''
#     CREATE TABLE Movie_info(
#     Index varchar(255) 
#     Movie)
# '''

# %%
import requests

url = "https://www.imdb.com/chart/top/?sort=rk,asc&mode=simple&page=1"
page = requests.get(url)
page.content
# Out:
# b'\n\n\n<!DOCTYPE html>\n<html\n    xmlns:og="http://ogp.me/ns#"\n    xmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n         \n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    \n    \n    \n\n    \n    \n    \n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">\n            <style>\n                body#styleguide-v2 {\n                    background: no-repeat fixed center top #000;\n                }\n            </style>\n\n\n\n        <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:\'java\'};</script>\n\n<script>\n    if (typeof uet == \'function\') {\n      uet("bb", "LoadTitle", {wb: 1});\n    }\n</script>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>\n        <title>IMDb Top 250 - IMDb</title>\n  <script>(function(t){ (t.events = t.events || {})["csm_head_post_t
# ...

# %%
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup as bs
soup = bs(page.content, 'html.parser')
titleColumn = soup.find_all("td" ,class_="titleColumn")
titleColumn
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>, <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>, <td class="titleColumn">
#        3.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>, <td class="titleColumn">
#        4.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>, <td class="titleColumn">
#        5.
# ...

# %% [markdown]
# # Get movie name

# %%
name_list = []
for i in range(len(titleColumn)):
    get_text = titleColumn[i].get_text().split('\n')[2].strip()
    name_list.append(get_text)
print(name_list)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Godfather: Part II', 'The Dark Knight', '12 Angry Men', "Schindler's List", 'The Lord of the Rings: The Return of the King', 'Pulp Fiction', 'The Good, the Bad and the Ugly', 'Fight Club', 'The Lord of the Rings: The Fellowship of the Ring', 'Forrest Gump', 'Inception', 'Star Wars: Episode V - The Empire Strikes Back', 'The Lord of the Rings: The Two Towers', 'The Matrix', 'Goodfellas', "One Flew Over the Cuckoo's Nest", 'Joker', 'Seven Samurai', 'Se7en', 'City of God', 'Life Is Beautiful', 'The Silence of the Lambs', "It's a Wonderful Life", 'Star Wars: Episode IV - A New Hope', 'Saving Private Ryan', 'Spirited Away', 'The Green Mile', 'Interstellar', 'Léon: The Professional', 'The Usual Suspects', 'Harakiri', 'Parasite', 'The Lion King', 'American History X', 'Back to the Future', 'Terminator 2: Judgment Day', 'The Pianist', 'Modern Times', 'Psycho', 'The Intouchables', 'Gladiator', 'City Lights', 'The Departed', 'Whiplash', 'Once 
# ...

# %%
len(name_list)
# Out:
# 250

# %%
titleColumn[0].get_text().split('\n')[2].strip()
# Out:
# 'The Shawshank Redemption'

# %%
def get_urls(data):
    links1 = []
    for i in range(len(data)):
        for link in data[i].find_all('a'):
            k = link.get('href')
        links1.append(k)
    print(links1)
get_urls(titleColumn)
# Out:
# ['/title/tt0111161/', '/title/tt0068646/', '/title/tt0071562/', '/title/tt0468569/', '/title/tt0050083/', '/title/tt0108052/', '/title/tt0167260/', '/title/tt0110912/', '/title/tt0060196/', '/title/tt0137523/', '/title/tt0120737/', '/title/tt0109830/', '/title/tt1375666/', '/title/tt0080684/', '/title/tt0167261/', '/title/tt0133093/', '/title/tt0099685/', '/title/tt0073486/', '/title/tt7286456/', '/title/tt0047478/', '/title/tt0114369/', '/title/tt0317248/', '/title/tt0118799/', '/title/tt0102926/', '/title/tt0038650/', '/title/tt0076759/', '/title/tt0120815/', '/title/tt0245429/', '/title/tt0120689/', '/title/tt0816692/', '/title/tt0110413/', '/title/tt0114814/', '/title/tt0056058/', '/title/tt6751668/', '/title/tt0110357/', '/title/tt0120586/', '/title/tt0088763/', '/title/tt0103064/', '/title/tt0253474/', '/title/tt0027977/', '/title/tt0054215/', '/title/tt1675434/', '/title/tt0172495/', '/title/tt0021749/', '/title/tt0407887/', '/title/tt2582802/', '/title/tt0064116/', '/title/tt
# ...

# %%
split = get_text.split('\n')[2].strip()
split
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-a4911aa35c09> in <module>
# ----> 1 split = get_text.split('\n')[2].strip()
#       2 split
#
# IndexError: list index out of range

# %%
titleColumn[0].get_text().split('\n')[2].strip()
# Out:
# 'The Shawshank Redemption'

# %% [markdown]
# Get rating

# %%
imdb_ratings = soup.find_all(class_="ratingColumn imdbRating")
imdb_ratings
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 2,167,090 user ratings">9.2</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.1 based on 1,488,076 user ratings">9.1</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 1,036,582 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,142,298 user ratings">9.0</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 620,908 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,124,787 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,538,709 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,701,491 user ratings">8.9</strong>
#  </td>, <td class="ratingColumn imdbRating">
# ...

# %%
imdb_ratings[0].get_text().strip()
# Out:
# '9.2'

# %%
#get the IMDB ratings for 250 top rated movies (IMDB) -> ratings


ratings = []
for i in range(len(imdb_ratings)):
    r = imdb_ratings[i].get_text().strip()
    ratings.append(r)
ratings
# Out:
# ['9.2',
#  '9.1',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.2',
#  '8.2',
# ...

# %% [markdown]
# Find Movie year

# %%
# find the year for top 250 rated movies
years = soup.find_all(class_='secondaryInfo')
years[0].get_text().strip('()')
# Out:
# '1994'

# %%
#check 
len(years)
# Out:
# 250

# %% [markdown]
# combined movie name, imdb_rating and years

# %%
title = titleColumn[0].get_text().split('\n')[2].strip()
rating = imdb_ratings[i].get_text().strip()
year = years[i].get_text().strip('()')

# %%
#get the year list for 250 top rated movies (IMDB) -> year_list
year_list = []
for year in years:
    y = year.string.strip('()')
    year_list.append(y)
print(year_list)
# Out:
# ['1994', '1972', '1974', '2008', '1957', '1993', '2003', '1994', '1966', '1999', '2001', '1994', '2010', '1980', '2002', '1999', '1990', '1975', '2019', '1954', '1995', '2002', '1997', '1991', '1946', '1977', '1998', '2001', '1999', '2014', '1994', '1995', '1962', '2019', '1994', '1998', '1985', '1991', '2002', '1936', '1960', '2011', '2000', '1931', '2006', '2014', '1968', '2006', '1942', '1988', '1954', '1988', '1979', '1981', '1979', '2000', '1940', '2019', '2006', '2012', '2018', '1980', '1957', '2018', '2008', '1950', '1997', '1964', '2003', '1957', '2012', '1984', '1986', '1999', '2016', '2017', '1995', '1981', '2009', '1983', '2007', '1995', '1984', '1992', '2009', '1997', '1931', '2000', '1968', '2016', '1958', '2004', '1941', '2012', '1987', '1959', '1971', '2000', '1921', '1948', '2001', '1983', '1952', '1976', '1962', '2010', '1973', '1927', '1965', '1944', '2011', '1952', '2019', '2018', '1962', '1960', '1989', '2009', '2010', '1997', '1975', '1995', '1950', '1988', '2005
# ...

# %%
#get the IMDB ratings for 250 top rated movies (IMDB)
soup.find_all('strong')[0].string
# Out:
# '9.2'

# %%
#check how many user ratings (one rating per movie); should match 250
len(imdb_ratings)
# Out:
# 250

# %%
titleColumn = soup.find_all(class_='titleColumn')
titleColumn
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>, <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>, <td class="titleColumn">
#        3.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>, <td class="titleColumn">
#        4.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>, <td class="titleColumn">
#        5.
# ...

# %%
titleColumn = soup.find_all(class_='titleColumn')
string1 = titleColumn[0].find_all('a')
string1
# Out:
# [<a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>]

# %%
len(titleColumn)
# Out:
# 250

# %%
links1 = []
for i in range(len(titleColumn)):
    for link in titleColumn[i].find_all('a'):
        k = link.get('href')
        k = 'https://www.imdb.com'+k
    links1.append(k)
links1
# Out:
# ['https://www.imdb.com/title/tt0111161/',
#  'https://www.imdb.com/title/tt0068646/',
#  'https://www.imdb.com/title/tt0071562/',
#  'https://www.imdb.com/title/tt0468569/',
#  'https://www.imdb.com/title/tt0050083/',
#  'https://www.imdb.com/title/tt0108052/',
#  'https://www.imdb.com/title/tt0167260/',
#  'https://www.imdb.com/title/tt0110912/',
#  'https://www.imdb.com/title/tt0060196/',
#  'https://www.imdb.com/title/tt0137523/',
#  'https://www.imdb.com/title/tt0120737/',
#  'https://www.imdb.com/title/tt0109830/',
#  'https://www.imdb.com/title/tt1375666/',
#  'https://www.imdb.com/title/tt0080684/',
#  'https://www.imdb.com/title/tt0167261/',
#  'https://www.imdb.com/title/tt0133093/',
#  'https://www.imdb.com/title/tt0099685/',
#  'https://www.imdb.com/title/tt0073486/',
#  'https://www.imdb.com/title/tt7286456/',
#  'https://www.imdb.com/title/tt0047478/',
#  'https://www.imdb.com/title/tt0114369/',
#  'https://www.imdb.com/title/tt0317248/',
# ...

# %%
soup.find_all('strong')[0].string
# Out:
# '9.2'

# %%
d = {'Movie':name_list, 'Release Year': year_list, "IMDB Rating": ratings, 'URL': links1}
d
# Out:
# {'Movie': ['The Shawshank Redemption',
#   'The Godfather',
#   'The Godfather: Part II',
#   'The Dark Knight',
#   '12 Angry Men',
#   "Schindler's List",
#   'The Lord of the Rings: The Return of the King',
#   'Pulp Fiction',
#   'The Good, the Bad and the Ugly',
#   'Fight Club',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Forrest Gump',
#   'Inception',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'The Lord of the Rings: The Two Towers',
#   'The Matrix',
#   'Goodfellas',
#   "One Flew Over the Cuckoo's Nest",
#   'Joker',
#   'Seven Samurai',
#   'Se7en',
#   'City of God',
#   'Life Is Beautiful',
#   'The Silence of the Lambs',
#   "It's a Wonderful Life",
#   'Star Wars: Episode IV - A New Hope',
#   'Saving Private Ryan',
#   'Spirited Away',
#   'The Green Mile',
#   'Interstellar',
#   'Léon: The Professional',
#   'The Usual Suspects',
#   'Harakiri',
#   'Parasite',
#   'The Lion King',
#   'American History X',
# ...

# %%
df = pd.DataFrame(d)
# name_list
# year_list
# ratings
# link1
df
# Out:
#                         Movie Release Year IMDB Rating  \
# 0    The Shawshank Redemption         1994         9.2
# 1               The Godfather         1972         9.1
# 2      The Godfather: Part II         1974         9.0
# 3             The Dark Knight         2008         9.0
# 4                12 Angry Men         1957         8.9
# ..                        ...          ...         ...
# 245                   Aladdin         1992         8.0
# 246   Guardians of the Galaxy         2014         8.0
# 247          Infernal Affairs         2002         8.0
# 248     The Battle of Algiers         1966         8.0
# 249         Castle in the Sky         1986         8.0
#
#                                        URL
# 0    https://www.imdb.com/title/tt0111161/
# 1    https://www.imdb.com/title/tt0068646/
# 2    https://www.imdb.com/title/tt0071562/
# 3    https://www.imdb.com/title/tt0468569/
# 4    https://www.imdb.com/title/tt0050083/
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=250, step=1)

# %%
df['IMDB Top 250 Rank'] = df.index+1
df
# Out:
#                         Movie Release Year IMDB Rating  \
# 0    The Shawshank Redemption         1994         9.2
# 1               The Godfather         1972         9.1
# 2      The Godfather: Part II         1974         9.0
# 3             The Dark Knight         2008         9.0
# 4                12 Angry Men         1957         8.9
# ..                        ...          ...         ...
# 245                   Aladdin         1992         8.0
# 246   Guardians of the Galaxy         2014         8.0
# 247          Infernal Affairs         2002         8.0
# 248     The Battle of Algiers         1966         8.0
# 249         Castle in the Sky         1986         8.0
#
#                                        URL  IMDB Top 250 Rank
# 0    https://www.imdb.com/title/tt0111161/                  1
# 1    https://www.imdb.com/title/tt0068646/                  2
# 2    https://www.imdb.com/title/tt0071562/                  3
# ...

# %%
list(df.columns)
# Out:
# ['Movie', 'Release Year', 'IMDB Rating', 'URL', 'IMDB Top 250 Rank']

# %%
#links1 is list of all urls
page = requests.get(df['URL'][0])
page.content 
soup = bs(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///title/tt0111161?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>The Shawshank Redemption (1994) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
#get list of countries
countries = []
for i in range(len(links1)):
    page = requests.get(df['URL'][i])
    page.content
    soup = bs(page.content, 'html.parser')
    
    titledetails = soup.find_all(class_='article', id='titleDetails')
    allhrefs = titledetails[0].find_all('a')
    country = allhrefs[2].string
    countries.append(country)
countries
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-638cd0753d5f> in <module>
#       4     page = requests.get(df['URL'][i])
#       5     page.content
# ----> 6     soup = bs(page.content, 'html.parser')
#       7
#       8     titledetails = soup.find_all(class_='article', id='titleDetails')
#
# /opt/anaconda3/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     301             self.reset()
#     302             try:
# --> 303                 self._feed()
#     304                 break
#     305             except ParserRejectedMarkup:
#
# /opt/anaconda3/lib/python3.7/site-packages/bs4/__init__.py in _feed(self)
#     362         self.builder.reset()
#     363
# --> 364         self.builder.feed(self.markup)
# ...

# %%
#get budget
import locale
locale.setlocale( locale.LC_ALL, 'en_US.UTF-8' )

string1 = titledetails[0].find_all(class_='txt-block')[6].get_text()
budget = string1.split('\n')[1].strip('Budget:').strip('$')
budget
budget1 = locale.atof(budget)
budget1

# %%
# g_data = soup.find_all('div',{'class':'info'})
# g_data

# %%
#examples:

# urls = ('div class="mb-movies"',id = 'featured-browse-ad-getter')
# url.find_all('div')
